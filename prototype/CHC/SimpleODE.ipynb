# %%
# %matplotlib inline
from matplotlib import pyplot as plt
from scipy.integrate import solve_ivp # for reference

import autograd.numpy as np
from neuralsolver import NNSolver
from sklearn.metrics import mean_squared_error
from math import sqrt
import time

# figure settings
plt.rcParams["figure.figsize"] = (8,6)
plt.rcParams['legend.fontsize'] = 13

plt.rcParams['xtick.labelsize'] = 13
plt.rcParams['ytick.labelsize'] = 13

plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.labelsize'] = 15

# %% [markdown]
# # Problem Definition

# %%
def f(t, y):
    # dx/dt = cos(t) + x^2 + y -(1 + t^2 + sin^2(t))
    # dt/dt = 2t - (1 + t^2)sin(t)+xy
    x = y[0]
    y = y[1]
    return [np.cos(t) + x**2 + y - (1 + t**2 + (np.sin(t))**2), 2*t - (1 + t**2)*np.sin(t) + x*y]

t = np.linspace(0, 3, 20).reshape(-1, 1) #training points
y0_list = [0, 1]

# %%
t_ = np.linspace(0, 3, 20)
sol1 = [np.sin(tt) for tt in t_]
sol2 = [1 + (tt**2) for tt in t_]
solActual = [sol1, sol2]

# %% [markdown]
# # Reference solution

# %%
# reference solution using scipy package
sol = solve_ivp(f, [t.min(), t.max()], y0_list, method='Radau', rtol=1e-5)
plt.plot(sol.t, sol.y[0], marker='o', label='ODE Solver - x')
plt.plot(sol.t, sol.y[1], marker='o', label='ODE Solver - y')
plt.plot(t_, sol1, label = 'Exact Solution - x')
plt.plot(t_, sol2, label = 'Exact Solution - y')
plt.xlabel('x')
plt.ylabel('Values')
plt.legend()

# %% [markdown]
# # Neural Net Training

# %%
nn = NNSolver(f, t, y0_list, n_hidden=50)
nn
# Out:
# Neural ODE Solver
# Number of equations:       2
# Initial condition y0:      [0, 1]
# Numnber of hidden units:   50
# Number of training points: 20

# %%
nn.reset_weights()
# %time nn.train(maxiter=1000, iprint=100)
# Out:
# iteration: 0 loss:  52.271404308
# iteration: 100 loss:  0.000114624786311
# iteration: 200 loss:  1.36400363324e-06
# iteration: 300 loss:  6.53080461044e-07
# iteration: 400 loss:  3.00040056725e-07
# iteration: 500 loss:  1.83182193865e-07
# iteration: 600 loss:  8.44491319587e-08
# iteration: 700 loss:  1.1985297071e-08
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 718
#          Function evaluations: 816
#          Gradient evaluations: 816
# CPU times: user 15.9 s, sys: 236 ms, total: 16.2 s
# Wall time: 12.4 s

# %% [markdown]
# # Verifying training set

# %%
y_pred_list, dydt_pred_list = nn.predict()

plt.figure(figsize=(8, 6))
# exact soln
plt.plot(t_, sol1, label = 'Exact Solution - x')
plt.plot(t_, sol2, label = 'Exact Solution - y')

# nn soln
plt.plot(t, y_pred_list[0], 'o', label='NN Solver - x')
plt.plot(t, y_pred_list[1], 'o', label='NN Solver - y')

plt.legend(loc = 'best')
plt.ylabel('Values of x and y')
plt.xlabel('t')
plt.title("Simple ODE System");

# %%
np.mean([sqrt(mean_squared_error(solActual[i], y_pred_list[i])) for i in range(2)])
# Out:
# 0.0524140323140935

# %%
# not included
t_test = np.linspace(0, 3.5, 21).reshape(-1,1)
y_pred_list, dydt_pred_list = nn.predict(t = t_test)

t_ = np.linspace(0, 3.5, 21)
sol1_test = [np.sin(tt) for tt in t_]
sol2_test = [1 + (tt**2) for tt in t_]

plt.plot(t_, sol1_test, label = 'Exact Solution - x')
plt.plot(t_, sol2_test, label = 'Exact Solution - y')

plt.plot(t_test, y_pred_list[0], 'o', label='NN Solver - x')
plt.plot(t_test, y_pred_list[1], 'o', label='NN Solver - y')
plt.axvline(x = 0, linestyle = '--')
plt.axvline(x = 3 , linestyle = '--')
plt.xlim((-0.1, 3.6))
plt.legend(loc = 'best')
plt.title('Simple ODE System')
plt.ylabel('Values of x and y')
plt.xlabel('t')

# %% [markdown]
# # Performance over 100 Fittings

# %%
res_arr = []
for _ in range(100):
    nn = NNSolver(f, t, y0_list, n_hidden=20)
    nn.reset_weights()
    nn.train(maxiter=500)
    y_pred_list, dydt_pred_list = nn.predict()
    res_arr.append(np.mean([sqrt(mean_squared_error(solActual[i], y_pred_list[i])) for i in range(2)]))
# Out:
# iteration: 0 loss:  64.3916359453
# iteration: 200 loss:  3.7522358992e-06
# iteration: 400 loss:  4.80590244823e-08
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 477
#          Function evaluations: 536
#          Gradient evaluations: 536
# iteration: 0 loss:  35.9483825332
# iteration: 200 loss:  1.76708902594e-06
# iteration: 400 loss:  3.10772157067e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 558
#          Gradient evaluations: 558
# iteration: 0 loss:  371.20871902
# iteration: 200 loss:  0.000211153184094
# iteration: 400 loss:  2.36191999291e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 560
#          Gradient evaluations: 560
# iteration: 0 loss:  8030.39055182
# iteration: 200 loss:  3.45487612516e-06
# iteration: 400 loss:  2.98150977527e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 556
#          Gradient evaluations: 556
# iteration: 0 loss:  35.3976285356
# iteration: 200 loss:  7.47924319035e-05
# iteration: 400 loss:  9.76314379671e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 561
#          Gradient evaluations: 561
# iteration: 0 loss:  946.942639006
# iteration: 200 loss:  8.63166739558e-06
# iteration: 400 loss:  1.31138411829e-07
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 467
#          Function evaluations: 522
#          Gradient evaluations: 522
# iteration: 0 loss:  95.5148711312
# iteration: 200 loss:  6.14416524299e-06
# iteration: 400 loss:  8.34454764541e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 556
#          Gradient evaluations: 556
# iteration: 0 loss:  24.6504248844
# iteration: 200 loss:  2.85964765356e-05
# iteration: 400 loss:  3.48519865815e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000002
#          Iterations: 500
#          Function evaluations: 556
#          Gradient evaluations: 556
# iteration: 0 loss:  8.04836342534
# iteration: 200 loss:  0.000148555531522
# iteration: 400 loss:  2.34538437027e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 557
#          Gradient evaluations: 557
# iteration: 0 loss:  62.308764994
# iteration: 200 loss:  3.78932606233e-05
# iteration: 400 loss:  2.45476312073e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 568
#          Gradient evaluations: 568
# iteration: 0 loss:  26.2927630968
# iteration: 200 loss:  7.9868777719e-06
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 361
#          Function evaluations: 416
#          Gradient evaluations: 416
# iteration: 0 loss:  137.663876206
# iteration: 200 loss:  1.26110289799e-05
# iteration: 400 loss:  2.9333563415e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 545
#          Gradient evaluations: 545
# iteration: 0 loss:  61.3409830215
# iteration: 200 loss:  0.00253879667607
# iteration: 400 loss:  6.79417928189e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000004
#          Iterations: 500
#          Function evaluations: 554
#          Gradient evaluations: 554
# iteration: 0 loss:  38.1105101465
# iteration: 200 loss:  3.59975745244e-06
# iteration: 400 loss:  5.76816962992e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 567
#          Gradient evaluations: 567
# iteration: 0 loss:  830.244168518
# iteration: 200 loss:  6.3639148328e-05
# iteration: 400 loss:  4.28006967011e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000002
#          Iterations: 500
#          Function evaluations: 551
#          Gradient evaluations: 551
# iteration: 0 loss:  11.7499729933
# iteration: 200 loss:  1.28427896577e-06
# iteration: 400 loss:  3.15330696261e-08
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 427
#          Function evaluations: 494
#          Gradient evaluations: 494
# iteration: 0 loss:  96.5439393399
# iteration: 200 loss:  0.000124572733014
# iteration: 400 loss:  1.2508946665e-05
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000005
#          Iterations: 500
#          Function evaluations: 557
#          Gradient evaluations: 557
# iteration: 0 loss:  857.008784194
# iteration: 200 loss:  0.000529883466754
# iteration: 400 loss:  3.04752926109e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 561
#          Gradient evaluations: 561
# iteration: 0 loss:  21.2366708712
# iteration: 200 loss:  2.16568511408e-06
# iteration: 400 loss:  1.80864274639e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 558
#          Gradient evaluations: 558
# iteration: 0 loss:  438.323843398
# iteration: 200 loss:  1.2530105134e-06
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 360
#          Function evaluations: 394
#          Gradient evaluations: 394
# iteration: 0 loss:  381.419095635
# iteration: 200 loss:  4.48163538208e-06
# iteration: 400 loss:  1.65367664397e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 577
#          Gradient evaluations: 577
# iteration: 0 loss:  3.12441286839
# iteration: 200 loss:  0.000107204002538
# iteration: 400 loss:  6.36952399441e-07
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 498
#          Function evaluations: 545
#          Gradient evaluations: 545
# iteration: 0 loss:  77.2976954395
# iteration: 200 loss:  0.000154080578257
# iteration: 400 loss:  3.06260291316e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000002
#          Iterations: 500
#          Function evaluations: 565
#          Gradient evaluations: 565
# iteration: 0 loss:  8467.82453631
# iteration: 200 loss:  5.41645988767e-06
# iteration: 400 loss:  9.39995326853e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 563
#          Gradient evaluations: 563
# iteration: 0 loss:  42.6934175002
# iteration: 200 loss:  1.84398996058e-06
# iteration: 400 loss:  6.04426296834e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 565
#          Gradient evaluations: 565
# iteration: 0 loss:  58.5806008394
# iteration: 200 loss:  6.22217038531e-07
# iteration: 400 loss:  3.54545762428e-08
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 412
#          Function evaluations: 473
#          Gradient evaluations: 473
# iteration: 0 loss:  14.7512159905
# iteration: 200 loss:  0.000844660193395
# iteration: 400 loss:  1.37817897235e-05
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000007
#          Iterations: 500
#          Function evaluations: 554
#          Gradient evaluations: 554
# iteration: 0 loss:  65.2174522303
# iteration: 200 loss:  6.98349462253e-06
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 327
#          Function evaluations: 371
#          Gradient evaluations: 371
# iteration: 0 loss:  2252.40947351
# iteration: 200 loss:  0.000178965640703
# iteration: 400 loss:  2.97909905076e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 549
#          Gradient evaluations: 549
# iteration: 0 loss:  26.2104321472
# iteration: 200 loss:  6.0423364678e-06
# iteration: 400 loss:  1.89195353377e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 563
#          Gradient evaluations: 563
# iteration: 0 loss:  94.2907584254
# iteration: 200 loss:  2.88024680125e-06
# iteration: 400 loss:  4.90058037123e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 555
#          Gradient evaluations: 555
# iteration: 0 loss:  106.034088848
# iteration: 200 loss:  3.58327434515e-06
# iteration: 400 loss:  5.11498648227e-08
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 441
#          Function evaluations: 486
#          Gradient evaluations: 486
# iteration: 0 loss:  126.844251316
# iteration: 200 loss:  2.44969585646e-05
# iteration: 400 loss:  6.41359841418e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 570
#          Gradient evaluations: 570
# iteration: 0 loss:  8.63382235871
# iteration: 200 loss:  8.74957735e-06
# iteration: 400 loss:  5.45653022651e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 567
#          Gradient evaluations: 567
# iteration: 0 loss:  22.0480208323
# iteration: 200 loss:  1.26220539292e-05
# iteration: 400 loss:  6.2666544411e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 556
#          Gradient evaluations: 556
# iteration: 0 loss:  6.65051505162
# iteration: 200 loss:  1.57412592429e-06
# iteration: 400 loss:  1.87213798048e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 572
#          Gradient evaluations: 572
# iteration: 0 loss:  30.6526906325
# iteration: 200 loss:  5.48501799686e-05
# iteration: 400 loss:  4.4851053825e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000003
#          Iterations: 500
#          Function evaluations: 554
#          Gradient evaluations: 554
# iteration: 0 loss:  14.363626096
# iteration: 200 loss:  3.45659132532e-06
# iteration: 400 loss:  3.81809176133e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 569
#          Gradient evaluations: 569
# iteration: 0 loss:  159.043603646
# iteration: 200 loss:  0.000749839994086
# iteration: 400 loss:  1.32009608166e-05
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000008
#          Iterations: 500
#          Function evaluations: 569
#          Gradient evaluations: 569
# iteration: 0 loss:  8224.91868911
# iteration: 200 loss:  0.000790332010168
# iteration: 400 loss:  1.1204849994e-05
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 564
#          Gradient evaluations: 564
# iteration: 0 loss:  9.23195018849
# iteration: 200 loss:  0.000543617309569
# iteration: 400 loss:  1.59724813479e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 547
#          Gradient evaluations: 547
# iteration: 0 loss:  38.5230948372
# iteration: 200 loss:  3.01621112684e-06
# iteration: 400 loss:  3.1920172242e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 559
#          Gradient evaluations: 559
# iteration: 0 loss:  40.5270676006
# iteration: 200 loss:  6.79747940695e-06
# iteration: 400 loss:  8.4878719727e-07
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 460
#          Function evaluations: 513
#          Gradient evaluations: 513
# iteration: 0 loss:  270.491559874
# iteration: 200 loss:  6.3471310891e-06
# iteration: 400 loss:  1.95108470757e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 554
#          Gradient evaluations: 554
# iteration: 0 loss:  41.4729276414
# iteration: 200 loss:  0.000194447646799
# iteration: 400 loss:  6.87686593627e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000005
#          Iterations: 500
#          Function evaluations: 558
#          Gradient evaluations: 558
# iteration: 0 loss:  164.672956048
# iteration: 200 loss:  2.07481502882e-05
# iteration: 400 loss:  1.85393495742e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 565
#          Gradient evaluations: 565
# iteration: 0 loss:  28.5518799107
# iteration: 200 loss:  5.40589644984e-06
# iteration: 400 loss:  2.92513998271e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 566
#          Gradient evaluations: 566
# iteration: 0 loss:  1159.07032997
# iteration: 200 loss:  0.116202709669
# iteration: 400 loss:  0.000684238620301
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000507
#          Iterations: 500
#          Function evaluations: 559
#          Gradient evaluations: 559
# iteration: 0 loss:  84.277483405
# iteration: 200 loss:  1.70839864105e-06
# iteration: 400 loss:  1.56199370168e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 558
#          Gradient evaluations: 558
# iteration: 0 loss:  133.824859163
# iteration: 200 loss:  0.000431394885318
# iteration: 400 loss:  4.11463696156e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000003
#          Iterations: 500
#          Function evaluations: 561
#          Gradient evaluations: 561
# iteration: 0 loss:  1698.04491203
# iteration: 200 loss:  2.52323162226e-05
# iteration: 400 loss:  2.16743770519e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 559
#          Gradient evaluations: 559
# iteration: 0 loss:  39.6502833151
# iteration: 200 loss:  0.00144319373024
# iteration: 400 loss:  8.13710727646e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000005
#          Iterations: 500
#          Function evaluations: 562
#          Gradient evaluations: 562
# iteration: 0 loss:  40.5811669026
# iteration: 200 loss:  7.94512432711e-06
# iteration: 400 loss:  8.18300767758e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 555
#          Gradient evaluations: 555
# iteration: 0 loss:  44.2597325512
# iteration: 200 loss:  5.04226904509e-06
# iteration: 400 loss:  6.96542356517e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 567
#          Gradient evaluations: 567
# iteration: 0 loss:  50.2079367721
# iteration: 200 loss:  6.82936747364e-06
# iteration: 400 loss:  3.01965911987e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 568
#          Gradient evaluations: 568
# iteration: 0 loss:  145.231943186
# iteration: 200 loss:  8.20169191766e-06
# iteration: 400 loss:  9.33763443382e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 547
#          Gradient evaluations: 547
# iteration: 0 loss:  65.5379551008
# iteration: 200 loss:  0.000177848679811
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 359
#          Function evaluations: 402
#          Gradient evaluations: 402
# iteration: 0 loss:  90.0576302429
# iteration: 200 loss:  7.32707836139e-06
# iteration: 400 loss:  1.62231096099e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 567
#          Gradient evaluations: 567
# iteration: 0 loss:  65.3570214427
# iteration: 200 loss:  0.000637052617676
# iteration: 400 loss:  5.92642539552e-05
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000025
#          Iterations: 500
#          Function evaluations: 563
#          Gradient evaluations: 563
# iteration: 0 loss:  17.9174710415
# iteration: 200 loss:  9.15631234768e-07
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 377
#          Function evaluations: 429
#          Gradient evaluations: 429
# iteration: 0 loss:  55.9539067703
# iteration: 200 loss:  3.59086229635e-05
# iteration: 400 loss:  2.27365031175e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 552
#          Gradient evaluations: 552
# iteration: 0 loss:  311.006423426
# iteration: 200 loss:  1.1053984074e-06
# iteration: 400 loss:  2.83029811646e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 565
#          Gradient evaluations: 565
# iteration: 0 loss:  115.906111553
# iteration: 200 loss:  3.08837096107e-06
# iteration: 400 loss:  4.79143915345e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 567
#          Gradient evaluations: 567
# iteration: 0 loss:  112.093098506
# iteration: 200 loss:  3.1641938453e-05
# iteration: 400 loss:  1.39710182083e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 554
#          Gradient evaluations: 554
# iteration: 0 loss:  27.8682161877
# iteration: 200 loss:  0.000508294646672
# iteration: 400 loss:  1.32662664676e-05
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000003
#          Iterations: 500
#          Function evaluations: 549
#          Gradient evaluations: 549
# iteration: 0 loss:  9.19782218624
# iteration: 200 loss:  2.58793775619e-05
# iteration: 400 loss:  3.0399038455e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 556
#          Gradient evaluations: 556
# iteration: 0 loss:  121.326633176
# iteration: 200 loss:  0.000331806895348
# iteration: 400 loss:  2.07841320319e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 549
#          Gradient evaluations: 549
# iteration: 0 loss:  22.6061803579
# iteration: 200 loss:  1.70270015181e-06
# iteration: 400 loss:  2.70023134945e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 565
#          Gradient evaluations: 565
# iteration: 0 loss:  2334.30324286
# iteration: 200 loss:  0.000143589357143
# iteration: 400 loss:  8.51960763532e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000003
#          Iterations: 500
#          Function evaluations: 559
#          Gradient evaluations: 559
# iteration: 0 loss:  37.2281466049
# iteration: 200 loss:  0.000218954887603
# iteration: 400 loss:  5.53018820488e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000002
#          Iterations: 500
#          Function evaluations: 562
#          Gradient evaluations: 562
# iteration: 0 loss:  9.15934888686
# iteration: 200 loss:  8.97282971246e-05
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 357
#          Function evaluations: 411
#          Gradient evaluations: 411
# iteration: 0 loss:  36.6012875092
# iteration: 200 loss:  4.00968162205e-06
# iteration: 400 loss:  6.23234295466e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 552
#          Gradient evaluations: 552
# iteration: 0 loss:  114.060801115
# iteration: 200 loss:  0.000424369519938
# iteration: 400 loss:  6.4028338873e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000005
#          Iterations: 500
#          Function evaluations: 546
#          Gradient evaluations: 546
# iteration: 0 loss:  9987.78460619
# iteration: 200 loss:  2.49841528459e-05
# iteration: 400 loss:  2.51501197376e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000002
#          Iterations: 500
#          Function evaluations: 553
#          Gradient evaluations: 553
# iteration: 0 loss:  159.320572544
# iteration: 200 loss:  1.87423056361e-05
# iteration: 400 loss:  2.38530479313e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 560
#          Gradient evaluations: 560
# iteration: 0 loss:  7.77900253945
# iteration: 200 loss:  1.93921806582e-05
# iteration: 400 loss:  1.21032295997e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 568
#          Gradient evaluations: 568
# iteration: 0 loss:  18.6593885784
# iteration: 200 loss:  0.000155626435332
# iteration: 400 loss:  5.1263067997e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000003
#          Iterations: 500
#          Function evaluations: 562
#          Gradient evaluations: 562
# iteration: 0 loss:  2333.97325547
# iteration: 200 loss:  0.000232658628576
# iteration: 400 loss:  3.95998926858e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 559
#          Gradient evaluations: 559
# iteration: 0 loss:  127.886500835
# iteration: 200 loss:  2.65287213192e-05
# iteration: 400 loss:  1.14902259053e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 574
#          Gradient evaluations: 574
# iteration: 0 loss:  134.188901248
# iteration: 200 loss:  0.00631668168782
# iteration: 400 loss:  4.69244997324e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000002
#          Iterations: 500
#          Function evaluations: 562
#          Gradient evaluations: 562
# iteration: 0 loss:  872.174468936
# iteration: 200 loss:  7.32769844298e-06
# iteration: 400 loss:  7.82944647082e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 559
#          Gradient evaluations: 559
# iteration: 0 loss:  58.6851541778
# iteration: 200 loss:  1.20337398245e-06
# iteration: 400 loss:  3.28239180831e-08
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 450
#          Function evaluations: 505
#          Gradient evaluations: 505
# iteration: 0 loss:  29.6480635991
# iteration: 200 loss:  8.9958949232e-06
# iteration: 400 loss:  5.73230869864e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 564
#          Gradient evaluations: 564
# iteration: 0 loss:  364.568137888
# iteration: 200 loss:  0.000287133790704
# iteration: 400 loss:  2.60686335148e-05
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000013
#          Iterations: 500
#          Function evaluations: 567
#          Gradient evaluations: 567
# iteration: 0 loss:  77.4751802235
# iteration: 200 loss:  6.55725219617e-05
# iteration: 400 loss:  1.89435109297e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000001
#          Iterations: 500
#          Function evaluations: 555
#          Gradient evaluations: 555
# iteration: 0 loss:  1426.62772743
# iteration: 200 loss:  5.17940919385e-05
# iteration: 400 loss:  1.88276069921e-07
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 435
#          Function evaluations: 485
#          Gradient evaluations: 485
# iteration: 0 loss:  633.802953991
# iteration: 200 loss:  3.42711950712e-06
# iteration: 400 loss:  5.99327595036e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 564
#          Gradient evaluations: 564
# iteration: 0 loss:  62.2609359772
# iteration: 200 loss:  0.000934557854505
# iteration: 400 loss:  4.64133808398e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000003
#          Iterations: 500
#          Function evaluations: 553
#          Gradient evaluations: 553
# iteration: 0 loss:  4968.39620932
# iteration: 200 loss:  4.25837202903e-06
# iteration: 400 loss:  2.35900654869e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 565
#          Gradient evaluations: 565
# iteration: 0 loss:  74.0522284716
# iteration: 200 loss:  2.43557018114e-06
# iteration: 400 loss:  4.22475357512e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 566
#          Gradient evaluations: 566
# iteration: 0 loss:  1001.63768429
# iteration: 200 loss:  1.10289491644e-06
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 240
#          Function evaluations: 269
#          Gradient evaluations: 269
# iteration: 0 loss:  5.72938322367
# iteration: 200 loss:  0.00036696233281
# iteration: 400 loss:  1.8196619977e-06
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 469
#          Function evaluations: 528
#          Gradient evaluations: 528
# iteration: 0 loss:  296.897853437
# iteration: 200 loss:  1.9276303568e-06
# iteration: 400 loss:  5.20733686324e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 556
#          Gradient evaluations: 556
# iteration: 0 loss:  30.2922951005
# iteration: 200 loss:  0.00153283690863
# iteration: 400 loss:  5.99733438e-05
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000005
#          Iterations: 500
#          Function evaluations: 553
#          Gradient evaluations: 553
# iteration: 0 loss:  16.5732382208
# iteration: 200 loss:  3.41204617028e-06
# iteration: 400 loss:  1.80619336481e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 549
#          Gradient evaluations: 549
# iteration: 0 loss:  18.9959149225
# iteration: 200 loss:  5.74465529778e-06
# iteration: 400 loss:  8.93654465221e-07
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000000
#          Iterations: 500
#          Function evaluations: 565
#          Gradient evaluations: 565
# iteration: 0 loss:  298.911460462
# iteration: 200 loss:  0.000258150628937
# iteration: 400 loss:  1.40226541996e-05
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000002
#          Iterations: 500
#          Function evaluations: 563
#          Gradient evaluations: 563
# iteration: 0 loss:  263.889261564
# iteration: 200 loss:  0.00376163669314
# iteration: 400 loss:  4.2305032256e-05
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000009
#          Iterations: 500
#          Function evaluations: 563
#          Gradient evaluations: 563
# iteration: 0 loss:  2.73918524581
# iteration: 200 loss:  4.7275955706e-05
# iteration: 400 loss:  2.04693700823e-06
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.000002
#          Iterations: 500
#          Function evaluations: 564
#          Gradient evaluations: 564
# iteration: 0 loss:  29.141333681
# iteration: 200 loss:  4.88861289772e-07
# iteration: 400 loss:  2.70000893169e-08
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 441
#          Function evaluations: 499
#          Gradient evaluations: 499

# %%
plt.figure(figsize= (8, 6))
figur = plt.hist(res_arr, bins=10)
plt.title('Performance of NN Solver over 100 fittings')
plt.xlabel('Average RMSE')
plt.ylabel('Frequency')
print (figur)
# Out:
# (array([ 48.,   7.,   7.,   0.,   0.,   0.,   0.,   0.,   0.,  38.]), array([  6.64004018e-04,   3.78358840e-01,   7.56053676e-01,
#          1.13374851e+00,   1.51144335e+00,   1.88913818e+00,
#          2.26683302e+00,   2.64452786e+00,   3.02222269e+00,
#          3.39991753e+00,   3.77761237e+00]), <a list of 10 Patch objects>)

# %% [markdown]
# ## Compare across different optimization techniques

# %%
def plot_loss_compare(model, maxiter = 1000, iprint = 200):
    model.reset_weights()
    save_init_paras_list = model.params_list
    save_init_flattened_params = model.flattened_params
    
    
    methods = ['CG','BFGS','L-BFGS-B']
    
    plt.figure(figsize=(8,6))
    for method in methods:
        
        model.params_list = save_init_paras_list
        model.flattened_params = save_init_flattened_params
        
        start_time = time.time()
        model.train(method = method, maxiter=maxiter, iprint=iprint)
        duration = time.time() - start_time
        
        plt.semilogy(range(len(model.loss)), model.loss, label = method + ' (time = {}s'.format(round(duration,2)) + ')')
        
    plt.legend()
    plt.title("Log Loss Comparision", fontsize = 20 )
    plt.xlabel("Iteration")
    plt.ylabel("Log Loss")
    plt.show()

# %%
plot_loss_compare(nn)
# Out:
# iteration: 0 loss:  684.125650601
# iteration: 200 loss:  0.0106458914493
# iteration: 400 loss:  0.00512126417896
# iteration: 600 loss:  0.00295376991575
# iteration: 800 loss:  0.00142421986384
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.001026
#          Iterations: 1000
#          Function evaluations: 2166
#          Gradient evaluations: 2166
# iteration: 0 loss:  684.125650601
# iteration: 200 loss:  4.23233499533e-06
# iteration: 400 loss:  4.64926409048e-07
# iteration: 600 loss:  3.81781179317e-08
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 648
#          Function evaluations: 734
#          Gradient evaluations: 734
# iteration: 0 loss:  625.407436379
# iteration: 200 loss:  0.0839181824359
# iteration: 400 loss:  0.00938149557062
# iteration: 600 loss:  0.00169326486729
# iteration: 800 loss:  0.00101871794301
# iteration: 1000 loss:  0.00037587816812
